# %%
import wikipedia

# %%
p=wikipedia.page("List of medical abbreviations: A")
p.html()
# Out:
# '<div class="mw-parser-output"><div role="navigation" class="navbox" aria-labelledby="Medical_abbreviations" style="padding:3px"><table class="nowraplinks collapsible show navbox-inner" style="border-spacing:0;background:transparent;color:inherit"><tbody><tr><th scope="col" class="navbox-title" colspan="2"><div class="plainlinks hlist navbar mini"><ul><li class="nv-view"><a href="/wiki/Template:MedAbbrev" title="Template:MedAbbrev"><abbr title="View this template" style=";;background:none transparent;border:none;-moz-box-shadow:none;-webkit-box-shadow:none;box-shadow:none; padding:0;">v</abbr></a></li><li class="nv-talk"><a href="/wiki/Template_talk:MedAbbrev" title="Template talk:MedAbbrev"><abbr title="Discuss this template" style=";;background:none transparent;border:none;-moz-box-shadow:none;-webkit-box-shadow:none;box-shadow:none; padding:0;">t</abbr></a></li><li class="nv-edit"><a class="external text" href="//en.wikipedia.org/w/index.php?title=Template:MedAbbrev&amp;action=edi
# ...

# %%
wikipedia.search("List_of_medical_abbreviations")
# Out:
# ['List of medical abbreviations',
#  'List of medical abbreviations: Latin abbreviations',
#  'List of medical abbreviations: P',
#  'List of medical abbreviations: S',
#  'List of medical abbreviations: I',
#  'List of medical abbreviations: A',
#  'List of medical abbreviations: Q',
#  'List of medical abbreviations: N',
#  'List of medical abbreviations: B',
#  'List of medical abbreviations: M']

# %%
import requests
website_url = requests.get('https://en.wikipedia.org/wiki/List_of_medical_abbreviations:_A').text

# %%
website_url = requests.get('https://en.wikipedia.org/wiki/List_of_medical_abbreviations:_N').text
soup2 = BeautifulSoup(website_url,'lxml')

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(website_url,'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of medical abbreviations: A - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
#   </script>
#   <script>
# ...

# %%
My_table = soup2.find('table',{'class':'wikitable sortable'})
My_table
# Out:
# <table class="wikitable sortable">
# <caption>Sortable table
# </caption>
# <tbody><tr>
# <th scope="col">Abbreviation
# </th>
# <th scope="col">Meaning
# </th></tr>
# <tr>
# <td>Nφ</td>
# <td><a href="/wiki/Neutrophil" title="Neutrophil">Neutrophil</a>
# </td></tr>
# <tr>
# <td>Na</td>
# <td><a href="/wiki/Sodium" title="Sodium">sodium</a> (from Latin <i>natrium</i>)
# </td></tr>
# <tr>
# <td>NA</td>
# <td>negative appendectomy
# </td></tr>
# <tr>
# <td>NAAT</td>
# <td>nuclear acid amplification test
# </td></tr>
# <tr>
# <td>NABS</td>
# <td>normoactive bowel sounds
# </td></tr>
# <tr>
# <td>NAC</td>
# <td>n-acetyl cysteine
# </td></tr>
# <tr>
# <td>NAD</td>
# <td>no abnormality detected <br/> no apparent distress <br/> (and many variations of the above)
# </td></tr>
# <tr>
# <td>NAD<sup>+</sup></td>
# <td><a href="/wiki/Nicotinamide_adenine_dinucleotide" title="Nicotinamide adenine dinucleotide">nicotinamide adenine dinucleotide</a>
# </td></tr>
# <tr>
# <td>NAFLD</td>
# ...

# %%
str(My_table[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-e1adae939752> in <module>
# ----> 1 str(My_table[0])
#
# /usr/lib/python3/dist-packages/bs4/element.py in __getitem__(self, key)
#     956         """tag[key] returns the value of the 'key' attribute for the tag,
#     957         and throws an exception if it's not there."""
# --> 958         return self.attrs[key]
#     959
#     960     def __iter__(self):
#
# KeyError: 0

# %%
for i in My_table:
    print(str(i))
    print("********************")
# Out:
# ********************
# <caption>Sortable table
# </caption>
# ********************
#
#
# ********************
# <tbody><tr>
# <th scope="col">Abbreviation
# </th>
# <th scope="col">Meaning
# </th></tr>
# <tr>
# <td>ā</td>
# <td>(a with a bar over it) before (from <a href="/wiki/Latin" title="Latin">Latin</a> <i>ante</i>) <br/> <a class="extiw" href="https://en.wiktionary.org/wiki/before" title="wikt:before">before</a>
# </td></tr>
# <tr>
# <td>A</td>
# <td>assessment
# </td></tr>
# <tr>
# <td>ap</td>
# <td>apical
# </td></tr>
# <tr>
# <td valign="top">a.a.</td>
# <td>of each (from <a href="/wiki/Latin" title="Latin">Latin</a> <i>ana ana</i>) <br/> <a class="mw-redirect" href="/wiki/Amino_acids" title="Amino acids">amino acids</a>:
# <ul><li>A or Ala – <a href="/wiki/Alanine" title="Alanine">alanine</a></li>
# <li>C or Cys – <a href="/wiki/Cysteine" title="Cysteine">cysteine</a></li>
# <li>D or Asp – <a href="/wiki/Aspartic_acid" title="Aspartic acid">aspartic acid</a></li>
# ...

# %%
from lxml import etree
s = """<table>
  <tr><th>Event</th><th>Start Date</th><th>End Date</th></tr>
  <tr><td>a</td><td>b</td><td>c</td></tr>
  <tr><td>d</td><td>e</td><td>f</td></tr>
  <tr><td>g</td><td>h</td><td>i</td></tr>
</table>
"""
table = etree.HTML(str(My_table)).find("body/table")
rows = iter(table)
headers = [col.text for col in next(rows)]
for row in rows:
    values = [col.text for col in row]
    print (dict(zip(headers, values)))
# Out:
# {}

# %%
links = My_table.findAll('a')
links
# Out:
# [<a href="/wiki/Latin" title="Latin">Latin</a>,
#  <a class="extiw" href="https://en.wiktionary.org/wiki/before" title="wikt:before">before</a>,
#  <a href="/wiki/Latin" title="Latin">Latin</a>,
#  <a class="mw-redirect" href="/wiki/Amino_acids" title="Amino acids">amino acids</a>,
#  <a href="/wiki/Alanine" title="Alanine">alanine</a>,
#  <a href="/wiki/Cysteine" title="Cysteine">cysteine</a>,
#  <a href="/wiki/Aspartic_acid" title="Aspartic acid">aspartic acid</a>,
#  <a href="/wiki/Glutamic_acid" title="Glutamic acid">glutamic acid</a>,
#  <a href="/wiki/Phenylalanine" title="Phenylalanine">phenylalanine</a>,
#  <a href="/wiki/Histidine" title="Histidine">histidine</a>,
#  <a href="/wiki/Isoleucine" title="Isoleucine">isoleucine</a>,
#  <a href="/wiki/Lysine" title="Lysine">lysine</a>,
#  <a href="/wiki/Leucine" title="Leucine">leucine</a>,
#  <a href="/wiki/Methionine" title="Methionine">methionine</a>,
#  <a href="/wiki/Asparagine" title="Asparagine">asparagine</a>,
# ...

# %%
Countries = []
for link in links:
    Countries.append(link.get('title'))
    
print(Countries)
# Out:
# ['Latin', 'wikt:before', 'Latin', 'Amino acids', 'Alanine', 'Cysteine', 'Aspartic acid', 'Glutamic acid', 'Phenylalanine', 'Histidine', 'Isoleucine', 'Lysine', 'Leucine', 'Methionine', 'Asparagine', 'Pyrrolysine', 'Proline', 'Glutamine', 'Arginine', 'Serine', 'Threonine', 'Selenocysteine', 'Valine', 'Tryptophan', 'Tyrosine', 'Glycosylated hemoglobin', 'Artery', 'Aortic aneurysm', 'Antibiotic-associated diarrhea', 'Arterial insufficiency', 'Pseudomembranous colitis', 'Anatomical terms of location', 'Mental status examination', 'Abdomen', 'Abdomen', 'Abortion', 'Antibody', 'Abortion', 'ABC (medicine)', 'Aspiration biopsy', 'ABC (medicine)', 'Melanoma', 'ABCD rating', 'Prostate cancer', 'ABC (medicine)', 'Acinic cell carcinoma', 'Patient Protection and Affordable Care Act', 'Abdomen', 'Abdomen', 'Field dressing (bandage)', 'Endocarditis', 'Arterial blood gas', 'Acquired brain injury', 'Ankle brachial pressure index', 'Autologous bone marrow transplantation', 'Blood type', 'Aspergillosis
# ...

# %%
import pandas as pd
df = pd.DataFrame()
df['Country'] = Countries

df
# Out:
#                                     Country
# 0                                     Latin
# 1                               wikt:before
# 2                                     Latin
# 3                               Amino acids
# 4                                   Alanine
# 5                                  Cysteine
# 6                             Aspartic acid
# 7                             Glutamic acid
# 8                             Phenylalanine
# 9                                 Histidine
# 10                               Isoleucine
# 11                                   Lysine
# 12                                  Leucine
# 13                               Methionine
# 14                               Asparagine
# 15                              Pyrrolysine
# 16                                  Proline
# 17                                Glutamine
# 18                                 Arginine
# 19                                   Serine
# ...

# %%
t=pd.read_html(str(My_table))
t[0]
# Out:
#                 0                                                  1
# 0    Abbreviation                                            Meaning
# 1              Nφ                                         Neutrophil
# 2              Na                        sodium (from Latin natrium)
# 3             NaN                              negative appendectomy
# 4            NAAT                    nuclear acid amplification test
# 5            NABS                           normoactive bowel sounds
# 6             NAC                                  n-acetyl cysteine
# 7             NAD  no abnormality detected no apparent distress (...
# 8            NAD+                  nicotinamide adenine dinucleotide
# 9           NAFLD                  Non-alcoholic fatty liver disease
# 10            NAS                                      no added salt
# 11           NASH                      Non-alcoholic steatohepatitis
# 12             NB  newborn (infant) note well (please pay attenti...
# ...

# %%
t[0][t[0].iloc[:,0]=='AGA']
# Out:
#       0                                                  1
# 86  AGA  anti-gliadin antibodies appropriate gestationa...

# %%
t[0].ix[4][1]
# Out:
# /home/rishubj/.local/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 'of each (from Latin ana ana) amino acids: A or Ala – alanine C or Cys – cysteine D or Asp – aspartic acid E or Glu – glutamic acid F or Phe – phenylalanine H or His – histidine I or Ile – isoleucine K or Lys – lysine L or Leu – leucine M or Met – methionine N or Asn – asparagine O or Pyl – pyrrolysine P or Pro – proline Q or Gln – glutamine R or Arg – arginine S or Ser – serine T or Thr – threonine U or Sec – selenocysteine V or Val – valine W or Trp – tryptophan Y or Tyr – tyrosine'

# %%
parsed_table = soup2.find_all('table')[1] 
data = [[td
         for td in row.find_all('td')]
        for row in parsed_table.find_all('tr')]

# %%
import re

# %%
j=99
for s in str(data[j][0]).split('<br/>'):
    ss = BeautifulSoup(s)
    print(re.sub(r'[\(].*?[\)]', '', ss.get_text()))
    
for s in str(data[j][1]).split('<br/>'):
    ss = BeautifulSoup(s)
    print(re.sub(r'[\(].*?[\)]', '', ss.get_text()))
# Out:
# N&V
# n/v
# nausea and vomiting

# %%
list(data[10][1].stripped_strings)
# Out:
# ['no added', 'salt']

# %%
j=18
print (data[j][1])
[x for x in data[j][1].contents if getattr(x, 'name', None) != 'br']
# Out:
# <td><a href="/wiki/ABC_(medicine)" title="ABC (medicine)">airway, breathing, circulation</a> <br/> <a class="mw-redirect" href="/wiki/Aspiration_biopsy" title="Aspiration biopsy">aspiration biopsy</a> cytology
# </td>
# [<a href="/wiki/ABC_(medicine)" title="ABC (medicine)">airway, breathing, circulation</a>,
#  ' ',
#  ' ',
#  <a class="mw-redirect" href="/wiki/Aspiration_biopsy" title="Aspiration biopsy">aspiration biopsy</a>,
#  ' cytology\n']

# %%
df = pd.DataFrame(data[1:], columns=data[0])
print(df)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-49-e0b59d1d8d9b> in <module>
#       1
# ----> 2 df = pd.DataFrame(data[1:], columns=data[0])
#       3 print(df)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     385                     if is_named_tuple(data[0]) and columns is None:
#     386                         columns = data[0]._fields
# --> 387                     arrays, columns = _to_arrays(data, columns, dtype=dtype)
#     388                     columns = _ensure_index(columns)
#     389
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in _to_arrays(data, columns, coerce_float, dtype)
#    7473     if isinstance(data[0], (list, tuple)):
#    7474         return _list_to_arrays(data, columns, coerce_float=coerce_float,
# ...

# %%
import sys, random
abc=set('abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ')
dct={}
for i in range(2000):
    dct[''.join(random.sample(abc, 4))]=[''.join(random.sample(abc, 52)),''.join(random.sample(abc, 1))]

get_size(dct)
# Out:
# 569416

# %%
def get_size(obj, seen=None):
    """Recursively finds size of objects"""
    size = sys.getsizeof(obj)
    if seen is None:
        seen = set()
    obj_id = id(obj)
    if obj_id in seen:
        return 0
    # Important mark as seen *before* entering recursion to gracefully handle
    # self-referential objects
    seen.add(obj_id)
    if isinstance(obj, dict):
        size += sum([get_size(v, seen) for v in obj.values()])
        size += sum([get_size(k, seen) for k in obj.keys()])
    elif hasattr(obj, '__dict__'):
        size += get_size(obj.__dict__, seen)
    elif hasattr(obj, '__iter__') and not isinstance(obj, (str, bytes, bytearray)):
        size += sum([get_size(i, seen) for i in obj])
    return size

# %%
# Out:
# 720089

# %%
import importlib
importlib.reload(allacronyms)
# Out:
# <module 'allacronyms' from '/home/rishubj/research/text/allacronyms.py'>

# %%
from allacronyms import AllAcronyms

# %%
import allacronyms

from tabulate import tabulate
acron = allacronyms.AllAcronyms()

# GET RANDOM ABBREVIATION
Abbs = acron.getRandom()
Abbs
# print( tabulate( Abbs, headers=Abbs[0]._fields ) )

# # GET LIST OF AVAILABLE CATEGORIES
# Categories = acron.categories
# print( tabulate( [ [ x ] for x in Categories ], headers=['Categories'] ) )

# # SEARCH FOR DEFINITION
# Abb = acron.search( Keywords='FOR'
#                   ,Category='Organizations'
#                   ,Topic='Friendship' )
# if Abb != None:
#     print( Abb.definition )

# # SEARCH FOR ABBREVIATION
# Abb = acron.search( Keywords='Application Programming Interface' )
# if Abb != None:
#     print( Abb.abb )
#     print( Abb.definition )

# # SEARCH FOR TOPICS ABBREVIATION / DEFINITION FALLS UNDER
# Topics = acron.getTopics( Keywords='Peanut Butter and Jelly' )
# print( tabulate( [ [ x ] for x in Topics ], headers=['Topics'] ) )

# # SEARCH FOR TOP ABBREVIATIONS / DEFINITIONS
# Abbs = acron.search( Keywords='YOLO', Quantity=10 )
# if len( Abbs ) > 0:
#     print( tabulate( Abbs, headers=Abbs[0]._fields ) )
# Out:
# INIT
# https://www.allacronyms.com/aa-random-term?nocache=1
# <Response [403]>
# <Element html at 0x7fbdc4c6ea48>
# []
# []

# %%
print (acron.getTopics())
# Out:
# dict_keys([])
